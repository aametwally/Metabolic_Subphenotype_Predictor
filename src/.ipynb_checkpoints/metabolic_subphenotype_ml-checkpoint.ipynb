# %%
import os
import sys
import numpy as np
import scipy as sp
import pandas as pd


## Utilities
import timeit
import datetime
import time

import seaborn as sns
import pickle
import statsmodels.stats.multitest
import random
import matplotlib as plt
import matplotlib.pyplot as plt
from matplotlib import pyplot

from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

import sklearn as sk

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF

from sklearn import metrics

from sklearn.metrics import plot_roc_curve
from sklearn.metrics import auc

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV

from numpy import mean
from numpy import std
from numpy import absolute
from numpy import arange

# %%
## Set project Path and get datetimestamp
project_path = "/Users/ahmedm/Library/CloudStorage/Box-Box/Ahmed Metwally's Files/Stanford/cgm/43883/Manuscripts/Manuscript_1_MetabolicSubphenotyping/"
os.chdir(project_path)

#### Read metabolic indicators, incretin, ogtt features, and ogtt timeseries
metabolic_indicators = pd.read_csv("aggregated_metabolic_indicators__4_predictions_w_prs_01042022.csv")

ogtt_timeseries = pd.read_csv("ogtt_imputed_normalized_09102021.csv", index_col = 0)
ogtt_timeseries = ogtt_timeseries.transpose()
ogtt_features = pd.read_csv("ogtt_features_09102021.csv", index_col=0)

## Select the 31 subjects in our study 
ogtt_timeseries = ogtt_timeseries[ogtt_timeseries.index.isin(metabolic_indicators.SubjectID)]

## Prepare annotation columns for the classifiers
metabolic_indicators["ethnicity_numeric"] = 0
metabolic_indicators.ethnicity_numeric[metabolic_indicators.ethnicity=="Asian"] = 1
metabolic_indicators.ethnicity_numeric[metabolic_indicators.ethnicity=="Hispanic"] = 2

metabolic_indicators["muscle_ir_status"] = 0
metabolic_indicators.muscle_ir_status[metabolic_indicators.SSPG_class_2=="IR"] = 1

metabolic_indicators["ie_status"] = 0
metabolic_indicators.ie_status[metabolic_indicators.ie_3_classes=="Intermediate"] = 1
metabolic_indicators.ie_status[metabolic_indicators.ie_3_classes=="Dysfunction"] = 2

metabolic_indicators["di_status"] = 0
metabolic_indicators.di_status[metabolic_indicators.di_3classes=="Intermediate"] = 1
metabolic_indicators.di_status[metabolic_indicators.di_3classes=="Dysfunction"] = 2

metabolic_indicators["di_status_v2"] = 0
metabolic_indicators.di_status_v2[metabolic_indicators.di_3classes_v2=="Intermediate"] = 1
metabolic_indicators.di_status_v2[metabolic_indicators.di_3classes_v2=="Dysfunction"] = 2


metabolic_indicators["hepatic_ir_status"] = 0
metabolic_indicators.hepatic_ir_status[metabolic_indicators.hepatic_ir_3classes=="Intermediate"]=1
metabolic_indicators.hepatic_ir_status[metabolic_indicators.hepatic_ir_3classes=="IR"]=2

metabolic_indicators["hepatic_ir_status_v2"] = 0
metabolic_indicators.hepatic_ir_status_v2[metabolic_indicators.hepatic_ir_3classes_v2=="Intermediate"]=1
metabolic_indicators.hepatic_ir_status_v2[metabolic_indicators.hepatic_ir_3classes_v2=="IR"]=2


## Combine OGGT glucose timeseries with metadata
metabolic_indicators_ogtt_timeseries = ogtt_timeseries.merge(metabolic_indicators, left_on=ogtt_timeseries.index, right_on='SubjectID')
metabolic_indicators_ogtt_timeseries.index = metabolic_indicators_ogtt_timeseries["SubjectID"]
metabolic_indicators_ogtt_timeseries.head()

### Combine ogtt features info with metadata
metabolic_indicators_ogtt_features = metabolic_indicators.merge(ogtt_features, left_on='SubjectID', right_on=ogtt_features.index)

### Combine ogtt features info wih timeseries with metadata
metabolic_indicators_ogtt_features_timeseries = metabolic_indicators_ogtt_features.merge(ogtt_timeseries, left_on='SubjectID', right_on=ogtt_timeseries.index)
# Out:
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#########################################
## Prediction of metabolic Subphenotype (w/ gold standard comparison)
#########################################
### Defining various machine learning classifiers
subphenotypes = ["muscle_ir_status", "di_status", "ie_status", "hepatic_ir_status", 'hepatic_ir_status_v2']
features_list = ["demographics_lab", "demographics", "lab", "homair", "homab", "matsuda", "incretins", "ogtt_timeseries", "ogtt_features", "PRS"]


random.seed(10)
num_iterations = 20
num_folds = 4
C = 10
kernel = 1.0 * RBF(1)
classifiers = {
    'L1_logistic': LogisticRegression(C=C, penalty='l1',
                                      solver='saga',
                                      #multi_class='multinomial',
                                      max_iter=10000),
    'L2_Logistic': LogisticRegression(C=C, penalty='l2',
                                                    solver='saga',
                                                    #multi_class='multinomial',
                                                    max_iter=10000),
    'Linear_SVC': SVC(kernel='linear', C=C, probability=True,
                      random_state=0),
    'RBF_SVC': SVC(kernel='rbf', C=C, probability=True,
                      random_state=0),#,
    'GPC': GaussianProcessClassifier(kernel, warm_start = True, random_state = 23234)
}


### Prepare files for logging evaluation results:
datetime_stmp = str(datetime.datetime.now())
datetime_stmp = datetime_stmp.replace(" ", "_")
datetime_stmp = datetime_stmp.replace(":", "-")
datetime_stmp = datetime_stmp.split('.')[0]


f = open("/Users/ahmedm/Documents/" + datetime_stmp + "_iterations_"+ str(num_iterations) + "_ML_Performance.csv", "a")
f.write("Features,Subphenotype,Iteration,Fold,Classifier,auROC,Accuracy,Recall_macro,Precision_macro,F1_macro,Recall_micro,Precision_micro,F1_micro" + "\n")
f.close()
for features in features_list:
    for subphenotype in subphenotypes:
        if features == "demographics_lab": 
            tmp = metabolic_indicators[["age", "sex_01", "bmi", "PreDM_T2D_history", "ethnicity_numeric", "a1c", "fpg", subphenotype]]
            tmp = tmp.dropna(axis=0)
            X = tmp[["age", "sex_01", "bmi", "PreDM_T2D_history", "ethnicity_numeric", "a1c", "fpg"]]
            y = tmp[subphenotype] 
        elif features == "demographics": 
            tmp = metabolic_indicators[["age", "sex_01", "bmi", "PreDM_T2D_history", "ethnicity_numeric", subphenotype]]
            tmp = tmp.dropna(axis=0)
            X = tmp[["age", "sex_01", "bmi", "PreDM_T2D_history", "ethnicity_numeric"]]
            y = tmp[subphenotype]
        elif features == "lab": 
            tmp = metabolic_indicators[["a1c", "fpg", subphenotype]]
            tmp = tmp.dropna(axis=0)
            X = tmp[["a1c", "fpg"]]
            y = tmp[subphenotype] 
        elif features == "homair":
            X = metabolic_indicators[["HOMA_IR"]]
            y = metabolic_indicators[subphenotype]
        elif features == "homab":
            X = metabolic_indicators[["HOMA_B"]]
            y = metabolic_indicators[subphenotype]
        elif features == "matsuda":
            X = metabolic_indicators[["matsuda_index"]]
            y = metabolic_indicators[subphenotype]
            
        elif features == "PRS":
            print("IN PRS")
            X = metabolic_indicators[["OR"]]
            y = metabolic_indicators[subphenotype]   
            
        elif features == "incretins":
            print("in incretins")        
            tmp = metabolic_indicators[['GLP1_120min', 'GIP_120min', subphenotype]]
            tmp = tmp.dropna(axis=0)
            X = tmp[['GLP1_120min', 'GIP_120min']]
            y = tmp[[subphenotype]]
        elif features == "ogtt_features":
            X = metabolic_indicators_ogtt_features[['ogtt_fpg', 'ogtt_60', 'ogtt_120',
                     'ogtt_180', 'ogtt_auc', 'ogtt_iauc', 'ogtt_pauc', 'ogtt_nauc',
                     'ogtt_max', 'ogtt_curve_size', 'ogtt_cv', 'ogtt_time_baseline_peak',
                     'ogtt_slope_baseline_peak','ogtt_slope_peak_last']]
            y = metabolic_indicators_ogtt_features[subphenotype]
        elif features == "ogtt_timeseries":
            X = metabolic_indicators_ogtt_timeseries.iloc[:,0:16]
            y = metabolic_indicators_ogtt_timeseries[subphenotype] 
        else:
            print("Wrong Featureset")
            exit(0)

        X = np.array(X)
        y = np.array(y)
        for j in range(num_iterations):
            skf = StratifiedKFold(n_splits=num_folds, shuffle = True, random_state= None)
            fold=0
            print("X.shape", X.shape)
            print("y.shape", y.shape)
            
            for train_index, test_index in skf.split(X, y):
                fold += 1
                if features == "ogtt":
                    x_train_tmp, x_test_tmp = X[train_index], X[test_index]
                    ogtt_pca = sk.decomposition.PCA()
                    principalComponents = ogtt_pca.fit_transform(x_train_tmp)
                    principalDf = pd.DataFrame(data = principalComponents)
                    principalDf
                    principalDf_2pcs = principalDf.loc[:,[0,1]]
                    principalDf_2pcs.columns = ["PC1", "PC2"]
                    x_train = principalDf_2pcs
                    test_principalComponents = ogtt_pca.transform(x_test_tmp)
                    test_principalDf = pd.DataFrame(data = test_principalComponents)
                    test_principalDf_2pcs = test_principalDf.loc[:,[0,1]]
                    test_principalDf_2pcs.columns = ["PC1", "PC2"]
                    x_test = test_principalDf_2pcs
                    y_train, y_test = y[train_index], y[test_index]
                else:
                    x_train, x_test = X[train_index], X[test_index]
                    y_train, y_test = y[train_index], y[test_index]

                for index, (name, classifier) in enumerate(classifiers.items()):
                    print("### Features=", features, "   Subphenotye=", subphenotype, "   Iteration = ", j, "   Fold = ", fold, "   classifier=", name)
                    classifier.fit(x_train, y_train)
                    y_pred_train = classifier.predict(x_train)
                    y_pred_test = classifier.predict(x_test)


                    ### Accuracy, AUC, Recall, Precision, F1
                    accuracy = metrics.accuracy_score(y_test, y_pred_test)
                    f1_macro = metrics.f1_score(y_test, y_pred_test, average = "macro")
                    f1_micro = metrics.f1_score(y_test, y_pred_test, average = "micro")
                    prec_macro = metrics.precision_score(y_test, y_pred_test, average = "macro")
                    prec_micro = metrics.precision_score(y_test, y_pred_test, average = "micro")
                    recall_macro = metrics.recall_score(y_test, y_pred_test, average = "macro")
                    recall_micro = metrics.recall_score(y_test, y_pred_test, average = "micro")

                    ## Confusion matrix
                    cm = metrics.confusion_matrix(y_test, y_pred_test)

                    # roc curve and auc
                    probs_test = classifier.predict_proba(x_test)
                    if subphenotype == "muscle_ir_status":
                        classifier_auc = metrics.roc_auc_score(y_test, probs_test[:, 1], multi_class='ovr')
                    else:
                        classifier_auc = metrics.roc_auc_score(y_test, probs_test, multi_class='ovr')


                    ## Logging evaluation results
                    f = open("/Users/ahmedm/Documents/" + datetime_stmp + "_iterations_"+ str(num_iterations) + "_ML_Performance.csv", "a")
                    f.write(features + "," + subphenotype + "," + str(j) + "," + str(fold) + "," + name + "," + str(round(classifier_auc,2)) +
                            ","+ str(round(accuracy,2)) +","+ str(round(recall_macro,2)) +","+ 
                            str(round(prec_macro,2)) +","+ str(round(f1_macro,2))+","+ str(round(recall_micro,2)) +
                            ","+ str(round(prec_micro,2)) +","+ str(round(f1_micro,2)) +"\n")
                    f.close()
# Out:
# IN PRS
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  3    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  0    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  3    classifier= L2_Logistic
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  1    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  2    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  1    classifier= Linear_SVC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  3    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  4    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  5    Fold =  4    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  4    classifier= L2_Logistic
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  6    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  3    classifier= L2_Logistic
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  7    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  8    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  9    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  10    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  3    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  11    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  3    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  12    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  13    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  3    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  14    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  3    classifier= RBF_SVC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  15    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  16    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  16    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  16    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  16    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= muscle_ir_status    Iteration =  16    Fold =  1    classifier= GPC
# ...
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  17    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  17    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  17    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  17    Fold =  4    classifier= GPC
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  1    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  2    classifier= GPC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  18    Fold =  4    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# X.shape (32, 1)
# y.shape (32,)
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  1    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  1    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  1    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  1    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  1    classifier= GPC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  2    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  2    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  2    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  2    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  2    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  3    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  3    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  3    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  3    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  3    classifier= GPC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  4    classifier= L1_logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  4    classifier= L2_Logistic
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  4    classifier= Linear_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  4    classifier= RBF_SVC
# ### Features= PRS    Subphenotye= hepatic_ir_status_v2    Iteration =  19    Fold =  4    classifier= GPC
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:409: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning)
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ahmedm/anaconda3/envs/tcr_ai/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
